# %%
import pickle
import pandas as pd

# %%
with open('bsc-3m/traj_01_elab.pkl', 'rb') as f:
    df = pickle.load(f)
for _ , n in df.iterrows():
    for i in range(len(n['xs'])):
        n['xs'][i]/=1280
        n['ys'][i]/=720

# %%
step_size = 15

x = df[['id', 'class', 'xs', 'ys']].loc[df['class'] == 'Car']
x['xs'] = x['xs'].str[::step_size]
x['ys'] = x['ys'].str[::step_size]


x['p_x'] = x['xs'].str[:-2]
x['p_y'] = x['ys'].str[:-2]
x['ds_x'] = x['xs'].str[-1]
x['ds_y'] = x['ys'].str[-1]
x['xs'] = x['xs'].str[1:-1]
x['ys'] = x['ys'].str[1:-1]



y = df[['xs', 'ys']].loc[df['class'] == 'Car']
y['xs'] = y['xs'].str[::step_size]
y['ys'] = y['ys'].str[::step_size]

y['t_x'] = y['xs'].str[2:]
y['t_y'] = y['ys'].str[2:]

asd = pd.concat((x,y[['t_x', 't_y']]),axis=1)

# %%
with open('jeff.pkl', 'wb') as f:
    pickle.dump(asd, f)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.model = nn.Sequential(
            nn.LSTM(6,50),
            nn.ReLU(),
            nn.Linear(50,2)
        )
    
    def forward(self, x):
        output = self.model(x)
        return output

# %%
model = Net()

optimizer = optim.SGD(model.parameters(), lr=0.01)
criterion = nn.MSELoss()

epochs = 20
for n in range(1, epochs+1):
    print('epoch:\t', n)
    input = torch.tensor([[[]]])
    for _, row in asd.iterrows():
        try:
            sample = torch.tensor([[
                row['xs'][i], 
                row['ys'][i], 
                row['p_x'][i], 
                row['p_y'][i], 
                row['ds_x'], 
                row['ds_y']] 
                for i in range(len(row['xs']))
            ]).float()

            sample[:,::2] /= 1280
            sample[:,1::2] /= 720

            target = torch.tensor([[
                row['t_x'][i], 
                row['t_y'][i]] 
                for i in range(len(row['xs']))
            ]).float()

            target[:,0] /= 1280
            target[:,1] /= 720
            
        except IndexError:
            continue

        
        optimizer.zero_grad()   # zero the gradient buffers
        output = model(sample.view(1, -1, 6))
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()    # Does the update
# Out:
# epoch:	 1
# C:\Users\marcu\anaconda3\lib\site-packages\torch\nn\modules\loss.py:520: UserWarning: Using a target size (torch.Size([78, 2])) that is different to the input size (torch.Size([1, 78, 2])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# C:\Users\marcu\anaconda3\lib\site-packages\torch\nn\modules\loss.py:520: UserWarning: Using a target size (torch.Size([74, 2])) that is different to the input size (torch.Size([1, 74, 2])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# ...

# %%
row = asd.iloc[100]
i = 0
sample = torch.tensor([[
    row['xs'][i], 
    row['ys'][i], 
    row['p_x'][i], 
    row['p_y'][i], 
    row['ds_x'], 
    row['ds_y']
]]).float()

sample[:,::2] /= 1280
sample[:,1::2] /= 720

print(sample)

for i in range(10):
    output = model(sample)
    sample_t = torch.tensor([[
        output[-1][0], 
        output[-1][1], 
        sample[-1][0], 
        sample[-1][1], 
        sample[-1][4], 
        sample[-1][5]
    ]]).float()
    sample = torch.concat((sample, sample_t))
# Out:
# tensor([[0.0301, 0.6231, 0.0047, 0.6231, 0.8766, 0.6431]])

# %%
import matplotlib.pyplot as plt
from PIL import Image, ImageOps

fig, ax = plt.subplots(figsize=(20,20))
im = Image.open("intersection2.png")
im = ImageOps.flip(im)
ax.set_xlim(0, 1280)
ax.set_ylim(0,720)
ax.imshow(im, origin='lower')


ax.plot(sample[:,0]*1280, sample[:,1]*720)
ax.plot(asd.iloc[100]['xs'], asd.iloc[100]['ys'])
